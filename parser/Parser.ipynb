# %% [markdown]
# # Парсинг HTML страниц

# %% [markdown]
# Во время путешествия по Турции я столкнулось с проблемой недостаточной релевантности комментариев о достопремечательностях с моей туристической реальностью. Было замечено, что местные жители отдают предпочтение совершенно другим местам, чем руско- и англоговорящие пользователи.
#
# Для того, чтобы сравнить как отличаются предпочтения разных языковых групп, мы выполним парсинг сайта **tripadvisor** по главным достопримечательностям Португалии.
#
# Выгружать будем будем комментарии на русском, португальском и английском языках.
#
# А так же данный проек демонстрирует как по названию достопримечательности ее можно искать на **googlemaps** и получать комментарии из данного источника.

# %% [markdown]
# ## 1. Импорт библиотек

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

import googlemaps
import geopandas as gpd
import geocoder

# %% [markdown]
# ## 2. Tripadvisor

# %% [markdown]
# Первая и последующие страницы для сайта Tripadvisor в разделе Attractions различаются, запишем 2 разных адреса. Помимо списка достопримечательностей с первой страницы, загрузим данные еще с 2х.

# %%
URL_1 = 'https://www.tripadvisor.com/Attractions-g189100-Activities-a_allAttractions.true-Portugal.html'
URL_2 = 'https://www.tripadvisor.com/Attractions-g189100-Activities-oa{}-Portugal.html'

HEADERS = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
          'assept' : '*/*'}

PAGE_COUNT = 2

# %%
def get_html(url, params=None):
    r = requests.get(url, headers=HEADERS, params=params)
    return r

def get_content(html):
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.find_all("article", class_="bMktZ bQbFd")
    place = []
    for item in items:
        place.append({
            'title': (re.sub(r'[0-9.]', '', item.find('div', class_='bUshh o csemS').get_text(strip=True))),
            'rating': item.find('svg', class_='RWYkj d H0').get('title')[0:3],
            'link': item.find('a').get('href'),
            'comment_count': item.find('span', class_='WlYyy diXIH bGusc bQCoY').get_text(strip=True).replace(',', ''),
            'category': item.find('div', class_='WlYyy diXIH fPixj').get_text(strip=True).replace(' • ', ', ')
        })
    return place

def parse():
    html = get_html(URL_1)
    if html.status_code == 200:
        pages_count = PAGE_COUNT
        place = []
        html = get_html(URL_1)
        print(f'Парсинг страницы 1 из {pages_count + 1}...')
        place.extend(get_content(html.text))
        for page in range(1, pages_count + 1):
            print(f'Парсинг страницы {page + 1} из {pages_count + 1}...')
            url = URL_2.format(page * 30)
            html = get_html(url)
            place.extend(get_content(html.text))
        return place
    else:
        print('Error')

d = parse()
# Out:
# Парсинг страницы 1 из 3...
# Парсинг страницы 2 из 3...
# Парсинг страницы 3 из 3...

# %%
tripadvisor  = pd.DataFrame(d)

# %%
tripadvisor.head(10)
# Out:
#                           title rating  \
# 0           Oceanário de Lisboa    4.5
# 1           Ponte de Dom Luís I    4.5
# 2              Praia Sao Rafael    4.5
# 3               Pico do Arieiro    4.5
# 4              Ponta da Piedade    5.0
# 5           Quinta da Regaleira    5.0
# 6         Animaris Ilha Deserta    4.5
# 7   Seven Hanging Valleys Trail    4.5
# 8               Krazy World Zoo    4.0
# 9   Fontes and Cascada da Risco    4.5
#
#                                                 link comment_count  \
# 0  /Attraction_Review-g189158-d195144-Reviews-Oce...         39856
# 1  /Attraction_Review-g189180-d636456-Reviews-Pon...         24582
# 2  /Attraction_Review-g189112-d3869627-Reviews-Pr...          1359
# 3  /Attraction_Review-g189167-d4740534-Reviews-Pi...          6707
# 4  /Attraction_Review-g189117-d1755231-Reviews-Po...          5464
# 5  /Attraction_Review-g189164-d484394-Reviews-Qui...         13418
# 6  /Attraction_Review-g189116-d3672317-Reviews-An...          1346
# 7  /Attraction_Review-g189111-d17378213-Reviews-S...            17
# 8  /Attraction_Review-g189111-d670139-Reviews-Kra...           401
# 9  /Attraction_Review-g189166-d548047-Reviews-25_...          1008
#
#                            category
# 0                         Aquariums
# 1                           Bridges
# 2                           Beaches
# 3                         Mountains
# 4               Geologic Formations
# 5  Architectural Buildings, Castles
# 6     Boat Tours, Speed Boats Tours
# 7                     Hiking Trails
# 8           Amusement & Theme Parks
# 9                     Hiking Trails

# %% [markdown]
# Мы выгрузили таблицу с:
# - названием достопримечательности,
# - общим рейтингом,
# - ссылкой на комментарии,
# - количество комментариев,
# - категорией достопримечательности.

# %% [markdown]
# Добавим в нашу таблицу комментарии на разных языках.

# %%
URL_list = list(tripadvisor['link'])
HOST = 'https://www.tripadvisor.{}'
domains = ['com', 'ru', 'pt']

def get_html(url, params=None):
    r = requests.get(url, headers=HEADERS, params=params)
    return r

def get_content(html):
    soup = BeautifulSoup(html, 'html.parser')
    place = []
    try:
        item = soup.find('div', class_='dHjBB')
        texts = item.find_all('span', class_='NejBf')
        ratings = item.find_all('svg', class_='RWYkj d H0')
        for i in range(0, len(texts)):
            place.append({
                'text': texts[i].get_text(strip=True),
                'rating': ratings[i].get('title')[0:3]
            })
        
    except:
        place.append('None')

    return place

def parse():
    html = get_html(host + URL_list[i])
    if html.status_code == 200:
        place = []
        place.extend(get_content(html.text))
        return place
    else:
        print('Error')
        
domain_dict = []
for domain in domains:  
    print(f'Парсинг комментариев домена {domain} ...')
    host = HOST.format(domain)
    d = []
    for i in range(0, len(URL_list)):
        x = parse()
        d.append(x)
    domain_dict.append({'domain_{}'.format(domain): d})
# Out:
# Парсинг комментариев домена com ...
# Парсинг комментариев домена ru ...
# Парсинг комментариев домена pt ...

# %%
tripadvisor['domain_com'] = pd.DataFrame(domain_dict[0])
tripadvisor['domain_ru'] = pd.DataFrame(domain_dict[1])
tripadvisor['domain_pt'] = pd.DataFrame(domain_dict[2])
tripadvisor.head(10)
# Out:
#                           title rating  \
# 0           Oceanário de Lisboa    4.5
# 1           Ponte de Dom Luís I    4.5
# 2              Praia Sao Rafael    4.5
# 3               Pico do Arieiro    4.5
# 4              Ponta da Piedade    5.0
# 5           Quinta da Regaleira    5.0
# 6         Animaris Ilha Deserta    4.5
# 7   Seven Hanging Valleys Trail    4.5
# 8               Krazy World Zoo    4.0
# 9   Fontes and Cascada da Risco    4.5
#
#                                                 link comment_count  \
# 0  /Attraction_Review-g189158-d195144-Reviews-Oce...         39856
# 1  /Attraction_Review-g189180-d636456-Reviews-Pon...         24582
# 2  /Attraction_Review-g189112-d3869627-Reviews-Pr...          1359
# 3  /Attraction_Review-g189167-d4740534-Reviews-Pi...          6707
# 4  /Attraction_Review-g189117-d1755231-Reviews-Po...          5464
# 5  /Attraction_Review-g189164-d484394-Reviews-Qui...         13418
# 6  /Attraction_Review-g189116-d3672317-Reviews-An...          1346
# 7  /Attraction_Review-g189111-d17378213-Reviews-S...            17
# 8  /Attraction_Review-g189111-d670139-Reviews-Kra...           401
# 9  /Attraction_Review-g189166-d548047-Reviews-25_...          1008
#
#                            category  \
# 0                         Aquariums
# 1                           Bridges
# 2                           Beaches
# 3                         Mountains
# 4               Geologic Formations
# 5  Architectural Buildings, Castles
# 6     Boat Tours, Speed Boats Tours
# 7                     Hiking Trails
# 8           Amusement & Theme Parks
# 9                     Hiking Trails
#
#                                           domain_com  \
# 0  [{'text': 'Incredible to see such an abundance...
# 1  [{'text': 'Worth a Walk', 'rating': '4.0'}, {'...
# 2  [{'text': 'Lovely beach!', 'rating': '5.0'}, {...
# 3  [{'text': 'Could this be more beautiful!', 'ra...
# 4  [{'text': 'Impressive rock formations that mus...
# 5  [{'text': 'Beautiful Palace and Grounds', 'rat...
# 6                                             [None]
# 7  [{'text': 'Breathtaking Grottos and panoramic ...
# 8  [{'text': 'Friendly with a personal touch', 'r...
# 9  [{'text': 'This trail has waterfalls, Leveda, ...
#
#                                            domain_ru  \
# 0  [{'text': 'Нам понравилось', 'rating': '5,0'},...
# 1  [{'text': 'Страшновато', 'rating': '5,0'}, {'t...
# 2  [{'text': 'Очень хорошо', 'rating': '5,0'}, {'...
# 3  [{'text': 'Волшебная Мадейра', 'rating': '5,0'...
# 4  [{'text': 'Самое красивое место', 'rating': '5...
# 5  [{'text': 'Мистическое место', 'rating': '5,0'...
# 6                                             [None]
# 7  [{'text': 'Breathtaking Grottos and panoramic ...
# 8  [{'text': 'Детям очень понравилось', 'rating':...
# 9  [{'text': 'Левада 25 водопадов', 'rating': '5,...
#
#                                            domain_pt
# 0  [{'text': 'Oceanário para todas as idades', 'r...
# 1  [{'text': 'excelente', 'rating': '4,0'}, {'tex...
# 2  [{'text': 'Pequeninas mas muito limpa', 'ratin...
# 3  [{'text': 'Local incrível', 'rating': '5,0'}, ...
# 4  [{'text': 'Paisagem magnífica', 'rating': '5,0...
# 5  [{'text': 'Maravilhoso!!!', 'rating': '5,0'}, ...
# 6                                             [None]
# 7  [{'text': 'Paradisíaco', 'rating': '4,0'}, {'t...
# 8  [{'text': 'Parque inseguro 😔 e com poucas medi...
# 9  [{'text': 'Levada 25 fontes', 'rating': '5,0'}...

# %%
tripadvisor[tripadvisor['domain_com'].apply(lambda x: x[0]) == 'None']
# Out:
#                    title rating  \
# 6  Animaris Ilha Deserta    4.5
#
#                                                 link comment_count  \
# 6  /Attraction_Review-g189116-d3672317-Reviews-An...          1346
#
#                         category domain_com domain_ru domain_pt
# 6  Boat Tours, Speed Boats Tours     [None]    [None]    [None]

# %% [markdown]
# Обнаружили предложение на бронирование лодочных туров. Они не совсем подгодят под наш запрос, удалим их.

# %%
none_index = list(tripadvisor[tripadvisor['domain_com'].apply(lambda x: x[0]) == 'None'].index)
tripadvisor = tripadvisor.query('index != @none_index').reset_index(drop=True)

# %%
tripadvisor.head(10)
# Out:
#                           title rating  \
# 0           Oceanário de Lisboa    4.5
# 1           Ponte de Dom Luís I    4.5
# 2              Praia Sao Rafael    4.5
# 3               Pico do Arieiro    4.5
# 4              Ponta da Piedade    5.0
# 5           Quinta da Regaleira    5.0
# 6   Seven Hanging Valleys Trail    4.5
# 7               Krazy World Zoo    4.0
# 8   Fontes and Cascada da Risco    4.5
# 9           Graham's Port Lodge    4.5
#
#                                                 link comment_count  \
# 0  /Attraction_Review-g189158-d195144-Reviews-Oce...         39856
# 1  /Attraction_Review-g189180-d636456-Reviews-Pon...         24582
# 2  /Attraction_Review-g189112-d3869627-Reviews-Pr...          1359
# 3  /Attraction_Review-g189167-d4740534-Reviews-Pi...          6707
# 4  /Attraction_Review-g189117-d1755231-Reviews-Po...          5464
# 5  /Attraction_Review-g189164-d484394-Reviews-Qui...         13418
# 6  /Attraction_Review-g189111-d17378213-Reviews-S...            17
# 7  /Attraction_Review-g189111-d670139-Reviews-Kra...           401
# 8  /Attraction_Review-g189166-d548047-Reviews-25_...          1008
# 9  /Attraction_Review-g580268-d3893366-Reviews-Gr...          2536
#
#                            category  \
# 0                         Aquariums
# 1                           Bridges
# 2                           Beaches
# 3                         Mountains
# 4               Geologic Formations
# 5  Architectural Buildings, Castles
# 6                     Hiking Trails
# 7           Amusement & Theme Parks
# 8                     Hiking Trails
# 9              Wineries & Vineyards
#
#                                           domain_com  \
# 0  [{'text': 'Incredible to see such an abundance...
# 1  [{'text': 'Worth a Walk', 'rating': '4.0'}, {'...
# 2  [{'text': 'Lovely beach!', 'rating': '5.0'}, {...
# 3  [{'text': 'Could this be more beautiful!', 'ra...
# 4  [{'text': 'Impressive rock formations that mus...
# 5  [{'text': 'Beautiful Palace and Grounds', 'rat...
# 6  [{'text': 'Breathtaking Grottos and panoramic ...
# 7  [{'text': 'Friendly with a personal touch', 'r...
# 8  [{'text': 'This trail has waterfalls, Leveda, ...
# 9  [{'text': 'The personal touch.', 'rating': '5....
#
#                                            domain_ru  \
# 0  [{'text': 'Нам понравилось', 'rating': '5,0'},...
# 1  [{'text': 'Страшновато', 'rating': '5,0'}, {'t...
# 2  [{'text': 'Очень хорошо', 'rating': '5,0'}, {'...
# 3  [{'text': 'Волшебная Мадейра', 'rating': '5,0'...
# 4  [{'text': 'Самое красивое место', 'rating': '5...
# 5  [{'text': 'Мистическое место', 'rating': '5,0'...
# 6  [{'text': 'Breathtaking Grottos and panoramic ...
# 7  [{'text': 'Детям очень понравилось', 'rating':...
# 8  [{'text': 'Левада 25 водопадов', 'rating': '5,...
# 9  [{'text': 'Увлекательная экскурсия в мир портв...
#
#                                            domain_pt
# 0  [{'text': 'Oceanário para todas as idades', 'r...
# 1  [{'text': 'excelente', 'rating': '4,0'}, {'tex...
# 2  [{'text': 'Pequeninas mas muito limpa', 'ratin...
# 3  [{'text': 'Local incrível', 'rating': '5,0'}, ...
# 4  [{'text': 'Paisagem magnífica', 'rating': '5,0...
# 5  [{'text': 'Maravilhoso!!!', 'rating': '5,0'}, ...
# 6  [{'text': 'Paradisíaco', 'rating': '4,0'}, {'t...
# 7  [{'text': 'Parque inseguro 😔 e com poucas medi...
# 8  [{'text': 'Levada 25 fontes', 'rating': '5,0'}...
# 9  [{'text': 'Adoramos a visita! Vinho incrível',...

# %% [markdown]
# ## GoogleMaps

# %% [markdown]
# Для загрузки данных можете истопользовать свой API.

# %%
gmaps = googlemaps.Client(key='AI***')

place_list = list(tripadvisor['title'])

# %%
place_dict = []

for p in range(0, len(place_list)):
    place_name = place_list[p]
    place_result = gmaps.places(place_name)
    if place_result['results'] != []:
        place_id = place_result['results'][0]['place_id']
        place = gmaps.place(place_id = place_id, language='en')
        try:
            reviews = place['result']['reviews']
            user_ratings_total = place['result']['user_ratings_total']
            types = place['result']['types']
            rating =  place['result']['rating']
            reviews_dict = []

            for i in range(len(reviews)):
                text = reviews[i]['text']
                rating = reviews[i]['rating']
                reviews_dict.append({'text': text,
                                     'rating': rating})
            place_dict.append({'place': place_name,
                               'rating': rating,
                               'types': types,
                               'user_ratings_total': user_ratings_total,
                               'reviews_en': reviews_dict})
        except:
            place_dict.append({'place': place_name,
                               'rating': 'No rating',
                               'types': 'No types',
                               'user_ratings_total': 'No ratings',
                               'reviews_en': 'No reviews'})

# %%
google_maps = pd.DataFrame(place_dict)
google_maps.head()

# %%
place_dict = []

for p in range(0, len(place_list)):
    place_name = place_list[p]
    place_result = gmaps.places(place_name)
    if place_result['results'] != []:
        place_id = place_result['results'][0]['place_id']
        place = gmaps.place(place_id = place_id, language='ru')
        try:
            reviews = place['result']['reviews']
            reviews_dict = []

            for i in range(len(reviews)):
                text = reviews[i]['text']
                rating = reviews[i]['rating']
                reviews_dict.append({'text': text,
                                     'rating': rating})
            place_dict.append({'reviews': reviews_dict})
        except:
            place_dict.append({'reviews': 'No reviews'})

# %%
place_dict

# %%
google_maps['reviews_ru'] = pd.DataFrame(place_dict)
google_maps.head()

# %%
place_dict = []

for p in range(0, len(place_list)):
    place_name = place_list[p]
    place_result = gmaps.places(place_name)
    if place_result['results'] != []:
        place_id = place_result['results'][0]['place_id']
        place = gmaps.place(place_id = place_id, language='pt')
        try:
            reviews = place['result']['reviews']
            reviews_dict = []

            for i in range(len(reviews)):
                text = reviews[i]['text']
                rating = reviews[i]['rating']
                reviews_dict.append({'text': text,
                                     'rating': rating})
            place_dict.append({'reviews': reviews_dict})
        except:
            place_dict.append({'reviews': 'No reviews'})

# %%
google_maps['reviews_pt'] = pd.DataFrame(place_dict)
google_maps.head()

# %%
google_maps[google_maps['reviews_ru'] == 'No reviews'].head()

# %%
google_maps.to_csv('google_maps.csv', index=False) 
tripadvisor.to_csv('tripadvisor.csv', index=False)

# %%
tripadvisor = pd.read_csv('tripadvisor.csv')
tripadvisor.head()
# Out:
#    Unnamed: 0                title  rating  \
# 0           0  Oceanário de Lisboa     4.5
# 1           1  Ponte de Dom Luís I     4.5
# 2           2     Praia Sao Rafael     4.5
# 3           3      Pico do Arieiro     4.5
# 4           4     Ponta da Piedade     5.0
#
#                                                 link  comment_count  \
# 0  /Attraction_Review-g189158-d195144-Reviews-Oce...          39835
# 1  /Attraction_Review-g189180-d636456-Reviews-Pon...          24566
# 2  /Attraction_Review-g189112-d3869627-Reviews-Pr...           1358
# 3  /Attraction_Review-g189167-d4740534-Reviews-Pi...           6703
# 4  /Attraction_Review-g189117-d1755231-Reviews-Po...           5460
#
#               category                                         domain_com  \
# 0            Aquariums  [{'text': "One of the best oceanariums I've be...
# 1              Bridges  [{'text': 'A beautiful bridge with many angles...
# 2              Beaches  [{'text': "We walked here one very hot morning...
# 3            Mountains  [{'text': 'As most have written in their revie...
# 4  Geologic Formations  [{'text': 'We walked to the site from our hote...
#
#                                            domain_ru  \
# 0  [{'text': 'Мой рекомендасьен! красиво очень! р...
# 1  [{'text': 'Не боялся высоты до этого моста. Ст...
# 2  [{'text': 'Отель на хорошую 8-ку. Замечательны...
# 3  [{'text': 'Будете на Мадейре - заходите на пик...
# 4  [{'text': 'Побережье в этом месте самое красив...
#
#                                            domain_pt
# 0  [{'text': 'Excelente para miúdos e graúdos. O ...
# 1  [{'text': 'Único! Experiência fora de série! F...
# 2  [{'text': 'Praia familiar e reservada, apesar ...
# 3  [{'text': 'Saí do Funchal de madrugada para as...
# 4  [{'text': 'São sempre dignas de deslumbramento...

# %%
google_maps = pd.read_csv('google_maps.csv')
google_maps.head()
# Out:
#                  place rating  \
# 0  Oceanário de Lisboa      4
# 1  Ponte de Dom Luís I      5
# 2     Praia Sao Rafael      5
# 3      Pico do Arieiro      4
# 4     Ponta da Piedade      5
#
#                                                types user_ratings_total  \
# 0  ['aquarium', 'tourist_attraction', 'point_of_i...              60249
# 1  ['tourist_attraction', 'point_of_interest', 'e...              56047
# 2  ['parking', 'point_of_interest', 'establishment']                 25
# 3               ['natural_feature', 'establishment']               1627
# 4  ['tourist_attraction', 'point_of_interest', 'e...              11375
#
#                                           reviews_en  \
# 0  [{'text': 'Fantastic aquarium, one of the best...
# 1  [{'text': 'A very impressive structure. Import...
# 2  [{'text': 'Hidden gem of Algarve, a small piec...
# 3  [{'text': 'Get there at least an hour before s...
# 4  [{'text': 'Place worth visiting if you are not...
#
#                                           reviews_ru  \
# 0  [{'text': 'Я с двумя детьми потратила около 4 ...
# 1  [{'text': 'Замечательный мост сам по себе, а т...
# 2  [{'text': 'Скрытая жемчужина Алгарве, маленьки...
# 3  [{'text': 'Облака и дождь, а так вообще красот...
# 4  [{'text': 'Место притягивает своими пейзажами,...
#
#                                           reviews_pt
# 0  [{'text': 'Sem dúvida um ponto de interesse a ...
# 1  [{'text': 'Vista deslumbrante abrangendo a lin...
# 2  [{'text': 'Praia pequena mas linda!', 'rating'...
# 3  [{'text': 'Pena não ter conseguido ver, estava...
# 4  [{'text': 'Lugar de paisagem ímpar... bastante...

# %% [markdown]
# В результате мы получили 2 таблицы с комментариями из двух источников. Осталось проанализировать полученные комментарии.
